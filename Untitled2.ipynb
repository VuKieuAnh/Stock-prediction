# %% [markdown]
# <a href="https://colab.research.google.com/github/VuKieuAnh/Stock-prediction/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #đọc dữ liệu
import numpy as np #xử lý dữ liệu
import matplotlib.pyplot as plt #vẽ biểu đồ
from sklearn.preprocessing import MinMaxScaler #chuẩn hóa dữ liệu
from keras.callbacks import ModelCheckpoint #lưu lại huấn luyện tốt nhất
from tensorflow.keras.models import load_model #tải mô hình

#các lớp để xây dựng mô hình
from keras.models import Sequential #đầu vào
from keras.layers import LSTM #học phụ thuộc
from keras.layers import Dropout #tránh học tủ
from keras.layers import Dense #đầu ra

#kiểm tra độ chính xác của mô hình
from sklearn.metrics import r2_score #đo mức độ phù hợp
from sklearn.metrics import mean_absolute_error #đo sai số tuyệt đối trung bình
from sklearn.metrics import mean_absolute_percentage_error #đo % sai số tuyệt đối trun

# %%
#tạo quyền truy cập với google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# đọc dữ liệu từ file csv
df = pd.read_csv('/content/drive/MyDrive/Kiều Anh P/Các lớp/Dữ liệu Lịch sử VNM 2013_2023.csv')

# Xóa hai dòng "KL" và "Thay đổi %" từ DataFrame dataSet
df = df.drop(columns=["KL", "% Thay đổi"])

# Hiển thị lại DataFrame sau khi xóa
print(df)
# Out:
#             Ngày  Đóng cửa    Mở cửa  Cao nhất Thấp nhất
# 0     21/07/2023  73,500.0  72,500.0  75,000.0  72,400.0
# 1     20/07/2023  72,700.0  72,600.0  72,900.0  72,300.0
# 2     19/07/2023  72,600.0  72,500.0  73,000.0  72,400.0
# 3     18/07/2023  72,400.0  72,500.0  72,600.0  72,200.0
# 4     17/07/2023  72,300.0  73,000.0  73,600.0  72,200.0
# ...          ...       ...       ...       ...       ...
# 2500  16/07/2013  96,528.0  95,139.0  97,222.0  95,139.0
# 2501  15/07/2013  95,139.0  95,139.0  95,833.0  94,444.0
# 2502  12/07/2013  95,139.0  94,444.0  95,139.0  93,750.0
# 2503  11/07/2013  94,444.0  94,444.0  95,139.0  93,750.0
# 2504  10/07/2013  94,444.0  95,139.0  95,833.0  94,444.0
#
# [2505 rows x 5 columns]

# %% [markdown]
# Tien xu ly du lieu

# %%
#định dạng cấu trúc thời gian
df["Ngày"] = pd.to_datetime(df.Ngày,format="%d/%m/%Y")
#kích thước dữ liệu
df.shape


#dữ liệu 5 dòng đầu
df.head()


#xác định kiểu dữ liệu
df.info()


#mô tả bộ dữ liệu
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2505 entries, 0 to 2504
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Ngày       2505 non-null   datetime64[ns]
#  1   Đóng cửa   2505 non-null   object
#  2   Mở cửa     2505 non-null   object
#  3   Cao nhất   2505 non-null   object
#  4   Thấp nhất  2505 non-null   object
# dtypes: datetime64[ns](1), object(4)
# memory usage: 98.0+ KB
# <ipython-input-5-c954db772280>:16: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   df.describe()
#                        Ngày  Đóng cửa    Mở cửa  Cao nhất Thấp nhất
# count                  2505      2505      2505      2505      2505
# unique                 2505      1250      1223      1300      1271
# top     2023-07-21 00:00:00  96,528.0  97,222.0  98,611.0  96,528.0
# freq                      1        34        33        34        42
# first   2013-07-10 00:00:00       NaN       NaN       NaN       NaN
# last    2023-07-21 00:00:00       NaN       NaN       NaN       NaN

# %%
from matplotlib.dates import YearLocator, DateFormatter, MonthLocator # Thêm MonthLocator vào để sửa lỗi

# Chuyển đổi cột "Ngày" sang dạng datetime
df['Ngày'] = pd.to_datetime(df['Ngày'], format='%d/%m/%Y')

# Sắp xếp lại dữ liệu theo thứ tự thời gian
df = df.sort_values(by='Ngày')

# Chuyển đổi định dạng các cột giá thành số thực
df['Đóng cửa'] = df['Đóng cửa'].str.replace(',', '').astype(float)
df['Mở cửa'] = df['Mở cửa'].str.replace(',', '').astype(float)
df['Cao nhất'] = df['Cao nhất'].str.replace(',', '').astype(float)
df['Thấp nhất'] = df['Thấp nhất'].str.replace(',', '').astype(float)

# Lấy thông tin năm từ cột "Ngày"
df['Năm'] = df['Ngày'].dt.year

# Tạo đồ thị giá đóng cửa qua các năm
plt.figure(figsize=(10, 5))
plt.plot(df['Ngày'], df['Đóng cửa'], label='Giá đóng cửa', color='red')
plt.xlabel('Năm')
plt.ylabel('Giá đóng cửa')
plt.title('Biểu đồ giá đóng cửa của VNM qua các năm')
plt.legend(loc='best')

# Định dạng đồ thị hiển thị các ngày tháng theo năm-tháng
years = YearLocator()
yearsFmt = DateFormatter('%Y')
months = MonthLocator()  # Thêm dòng này để khai báo MonthLocator
plt.gca().xaxis.set_major_locator(years)
plt.gca().xaxis.set_major_formatter(yearsFmt)
plt.gca().xaxis.set_minor_locator(months)

plt.tight_layout()
plt.show()

# %%
df1 = pd.DataFrame(df,columns=['Ngày','Đóng cửa'])
df1.index = df1.Ngày
df1.drop('Ngày',axis=1,inplace=True)
df1


#chia tập dữ liệu
data = df1.values
train_data = data[:1500]
test_data = data[1500:]


data


#chuẩn hóa dữ liệu
sc = MinMaxScaler(feature_range=(0,1))
sc_train = sc.fit_transform(data)


#tạo vòng lặp các giá trị
x_train,y_train=[],[]
for i in range(50,len(train_data)):
  x_train.append(sc_train[i-50:i,0]) #lấy 50 giá đóng cửa liên tục
  y_train.append(sc_train[i,0]) #lấy ra giá đóng cửa ngày hôm sau


x_train


y_train


#xếp dữ liệu thành 1 mảng 2 chiều
x_train = np.array(x_train)
y_train = np.array(y_train)

#xếp lại dữ liệu thành mảng 1 chiều
x_train = np.reshape(x_train,(x_train.shape[0],x_train.shape[1],1))
y_train = np.reshape(y_train,(y_train.shape[0],1))

# %% [markdown]
# Bước 5: Xây dựng và huấn luyện mô hình

# %%
#xây dựng mô hình
model = Sequential() #tạo lớp mạng cho dữ liệu đầu vào
#2 lớp LSTM
model.add(LSTM(units=128,input_shape=(x_train.shape[1],1),return_sequences=True))
model.add(LSTM(units=64))
model.add(Dropout(0.5)) #loại bỏ 1 số đơn vị tránh học tủ (overfitting)
model.add(Dense(1)) #output đầu ra 1 chiều
#đo sai số tuyệt đối trung bình có sử dụng trình tối ưu hóa adam
model.compile(loss='mean_absolute_error',optimizer='adam')


#huấn luyện mô hình
save_model = "/content/drive/MyDrive/dataset/save_model.hdf5"
best_model = ModelCheckpoint(save_model,monitor='loss',verbose=2,save_best_only=True,mode='auto')
model.fit(x_train,y_train,epochs=100,batch_size=50,verbose=2,callbacks=[best_model])


#dữ liệu train
y_train = sc.inverse_transform(y_train) #giá thực
final_model = load_model("/content/drive/MyDrive/dataset/save_model.hdf5")
y_train_predict = final_model.predict(x_train) #dự đoán giá đóng cửa trên tập đã train
y_train_predict = sc.inverse_transform(y_train_predict) #giá dự đoán
# Out:
# Epoch 1/100
#
# Epoch 1: loss improved from inf to 0.10060, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 6s - loss: 0.1006 - 6s/epoch - 204ms/step
# Epoch 2/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: loss improved from 0.10060 to 0.05295, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 5s - loss: 0.0529 - 5s/epoch - 170ms/step
# Epoch 3/100
#
# Epoch 3: loss did not improve from 0.05295
# 29/29 - 3s - loss: 0.0560 - 3s/epoch - 98ms/step
# Epoch 4/100
#
# Epoch 4: loss improved from 0.05295 to 0.05027, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0503 - 3s/epoch - 95ms/step
# Epoch 5/100
#
# Epoch 5: loss improved from 0.05027 to 0.04711, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0471 - 3s/epoch - 90ms/step
# Epoch 6/100
#
# Epoch 6: loss did not improve from 0.04711
# 29/29 - 3s - loss: 0.0472 - 3s/epoch - 108ms/step
# Epoch 7/100
#
# Epoch 7: loss improved from 0.04711 to 0.04654, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 5s - loss: 0.0465 - 5s/epoch - 176ms/step
# Epoch 8/100
#
# Epoch 8: loss did not improve from 0.04654
# 29/29 - 3s - loss: 0.0475 - 3s/epoch - 104ms/step
# Epoch 9/100
#
# Epoch 9: loss improved from 0.04654 to 0.04413, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0441 - 3s/epoch - 98ms/step
# Epoch 10/100
#
# Epoch 10: loss improved from 0.04413 to 0.04265, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0427 - 3s/epoch - 91ms/step
# Epoch 11/100
#
# Epoch 11: loss improved from 0.04265 to 0.04132, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 5s - loss: 0.0413 - 5s/epoch - 157ms/step
# Epoch 12/100
#
# Epoch 12: loss improved from 0.04132 to 0.03972, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0397 - 3s/epoch - 115ms/step
# Epoch 13/100
#
# Epoch 13: loss did not improve from 0.03972
# 29/29 - 3s - loss: 0.0403 - 3s/epoch - 91ms/step
# Epoch 14/100
#
# Epoch 14: loss improved from 0.03972 to 0.03949, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0395 - 3s/epoch - 92ms/step
# Epoch 15/100
#
# Epoch 15: loss improved from 0.03949 to 0.03812, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0381 - 3s/epoch - 93ms/step
# Epoch 16/100
#
# Epoch 16: loss improved from 0.03812 to 0.03690, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 5s - loss: 0.0369 - 5s/epoch - 183ms/step
# Epoch 17/100
#
# Epoch 17: loss improved from 0.03690 to 0.03654, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 4s - loss: 0.0365 - 4s/epoch - 125ms/step
# Epoch 18/100
#
# Epoch 18: loss improved from 0.03654 to 0.03631, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0363 - 3s/epoch - 94ms/step
# Epoch 19/100
#
# Epoch 19: loss improved from 0.03631 to 0.03534, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0353 - 3s/epoch - 92ms/step
# Epoch 20/100
#
# Epoch 20: loss did not improve from 0.03534
# 29/29 - 4s - loss: 0.0359 - 4s/epoch - 148ms/step
# Epoch 21/100
#
# Epoch 21: loss improved from 0.03534 to 0.03347, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 4s - loss: 0.0335 - 4s/epoch - 121ms/step
# Epoch 22/100
#
# Epoch 22: loss improved from 0.03347 to 0.03325, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0333 - 3s/epoch - 89ms/step
# Epoch 23/100
#
# Epoch 23: loss improved from 0.03325 to 0.03254, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0325 - 3s/epoch - 93ms/step
# Epoch 24/100
#
# Epoch 24: loss did not improve from 0.03254
# 29/29 - 3s - loss: 0.0353 - 3s/epoch - 91ms/step
# Epoch 25/100
#
# Epoch 25: loss improved from 0.03254 to 0.03116, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 5s - loss: 0.0312 - 5s/epoch - 181ms/step
# Epoch 26/100
#
# Epoch 26: loss did not improve from 0.03116
# 29/29 - 3s - loss: 0.0315 - 3s/epoch - 93ms/step
# Epoch 27/100
#
# Epoch 27: loss did not improve from 0.03116
# 29/29 - 3s - loss: 0.0321 - 3s/epoch - 91ms/step
# Epoch 28/100
#
# Epoch 28: loss did not improve from 0.03116
# 29/29 - 3s - loss: 0.0314 - 3s/epoch - 91ms/step
# Epoch 29/100
#
# Epoch 29: loss improved from 0.03116 to 0.02999, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 4s - loss: 0.0300 - 4s/epoch - 127ms/step
# Epoch 30/100
#
# Epoch 30: loss did not improve from 0.02999
# 29/29 - 4s - loss: 0.0303 - 4s/epoch - 148ms/step
# Epoch 31/100
#
# Epoch 31: loss did not improve from 0.02999
# 29/29 - 3s - loss: 0.0301 - 3s/epoch - 92ms/step
# Epoch 32/100
#
# Epoch 32: loss improved from 0.02999 to 0.02951, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0295 - 3s/epoch - 114ms/step
# Epoch 33/100
#
# Epoch 33: loss improved from 0.02951 to 0.02849, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0285 - 3s/epoch - 93ms/step
# Epoch 34/100
#
# Epoch 34: loss did not improve from 0.02849
# 29/29 - 5s - loss: 0.0287 - 5s/epoch - 166ms/step
# Epoch 35/100
#
# Epoch 35: loss did not improve from 0.02849
# 29/29 - 3s - loss: 0.0294 - 3s/epoch - 107ms/step
# Epoch 36/100
#
# Epoch 36: loss improved from 0.02849 to 0.02817, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0282 - 3s/epoch - 112ms/step
# Epoch 37/100
#
# Epoch 37: loss improved from 0.02817 to 0.02808, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0281 - 3s/epoch - 94ms/step
# Epoch 38/100
#
# Epoch 38: loss did not improve from 0.02808
# 29/29 - 4s - loss: 0.0291 - 4s/epoch - 123ms/step
# Epoch 39/100
#
# Epoch 39: loss did not improve from 0.02808
# 29/29 - 4s - loss: 0.0281 - 4s/epoch - 146ms/step
# Epoch 40/100
#
# Epoch 40: loss improved from 0.02808 to 0.02737, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0274 - 3s/epoch - 112ms/step
# Epoch 41/100
#
# Epoch 41: loss improved from 0.02737 to 0.02690, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0269 - 3s/epoch - 92ms/step
# Epoch 42/100
#
# Epoch 42: loss did not improve from 0.02690
# 29/29 - 3s - loss: 0.0271 - 3s/epoch - 91ms/step
# Epoch 43/100
#
# Epoch 43: loss improved from 0.02690 to 0.02613, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 5s - loss: 0.0261 - 5s/epoch - 172ms/step
# Epoch 44/100
#
# Epoch 44: loss did not improve from 0.02613
# 29/29 - 3s - loss: 0.0270 - 3s/epoch - 98ms/step
# Epoch 45/100
#
# Epoch 45: loss did not improve from 0.02613
# 29/29 - 3s - loss: 0.0263 - 3s/epoch - 91ms/step
# Epoch 46/100
#
# Epoch 46: loss did not improve from 0.02613
# 29/29 - 3s - loss: 0.0263 - 3s/epoch - 90ms/step
# Epoch 47/100
#
# Epoch 47: loss did not improve from 0.02613
# 29/29 - 3s - loss: 0.0267 - 3s/epoch - 99ms/step
# Epoch 48/100
#
# Epoch 48: loss improved from 0.02613 to 0.02534, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 5s - loss: 0.0253 - 5s/epoch - 184ms/step
# Epoch 49/100
#
# Epoch 49: loss did not improve from 0.02534
# 29/29 - 3s - loss: 0.0258 - 3s/epoch - 90ms/step
# Epoch 50/100
#
# Epoch 50: loss did not improve from 0.02534
# 29/29 - 3s - loss: 0.0260 - 3s/epoch - 91ms/step
# Epoch 51/100
#
# Epoch 51: loss improved from 0.02534 to 0.02501, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 4s - loss: 0.0250 - 4s/epoch - 121ms/step
# Epoch 52/100
#
# Epoch 52: loss improved from 0.02501 to 0.02452, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 5s - loss: 0.0245 - 5s/epoch - 161ms/step
# Epoch 53/100
#
# Epoch 53: loss did not improve from 0.02452
# 29/29 - 3s - loss: 0.0248 - 3s/epoch - 108ms/step
# Epoch 54/100
#
# Epoch 54: loss did not improve from 0.02452
# 29/29 - 3s - loss: 0.0249 - 3s/epoch - 91ms/step
# Epoch 55/100
#
# Epoch 55: loss improved from 0.02452 to 0.02373, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0237 - 3s/epoch - 108ms/step
# Epoch 56/100
#
# Epoch 56: loss did not improve from 0.02373
# 29/29 - 3s - loss: 0.0247 - 3s/epoch - 103ms/step
# Epoch 57/100
#
# Epoch 57: loss did not improve from 0.02373
# 29/29 - 5s - loss: 0.0247 - 5s/epoch - 166ms/step
# Epoch 58/100
#
# Epoch 58: loss did not improve from 0.02373
# 29/29 - 3s - loss: 0.0241 - 3s/epoch - 94ms/step
# Epoch 59/100
#
# Epoch 59: loss improved from 0.02373 to 0.02328, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0233 - 3s/epoch - 111ms/step
# Epoch 60/100
#
# Epoch 60: loss improved from 0.02328 to 0.02228, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0223 - 3s/epoch - 92ms/step
# Epoch 61/100
#
# Epoch 61: loss did not improve from 0.02228
# 29/29 - 4s - loss: 0.0235 - 4s/epoch - 137ms/step
# Epoch 62/100
#
# Epoch 62: loss did not improve from 0.02228
# 29/29 - 4s - loss: 0.0237 - 4s/epoch - 129ms/step
# Epoch 63/100
#
# Epoch 63: loss did not improve from 0.02228
# 29/29 - 3s - loss: 0.0240 - 3s/epoch - 104ms/step
# Epoch 64/100
#
# Epoch 64: loss did not improve from 0.02228
# 29/29 - 3s - loss: 0.0235 - 3s/epoch - 91ms/step
# Epoch 65/100
#
# Epoch 65: loss did not improve from 0.02228
# 29/29 - 3s - loss: 0.0239 - 3s/epoch - 91ms/step
# Epoch 66/100
#
# Epoch 66: loss improved from 0.02228 to 0.02206, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 5s - loss: 0.0221 - 5s/epoch - 182ms/step
# Epoch 67/100
#
# Epoch 67: loss did not improve from 0.02206
# 29/29 - 3s - loss: 0.0234 - 3s/epoch - 91ms/step
# Epoch 68/100
#
# Epoch 68: loss did not improve from 0.02206
# 29/29 - 3s - loss: 0.0228 - 3s/epoch - 90ms/step
# Epoch 69/100
#
# Epoch 69: loss did not improve from 0.02206
# 29/29 - 3s - loss: 0.0234 - 3s/epoch - 92ms/step
# Epoch 70/100
#
# Epoch 70: loss did not improve from 0.02206
# 29/29 - 3s - loss: 0.0237 - 3s/epoch - 119ms/step
# Epoch 71/100
#
# Epoch 71: loss did not improve from 0.02206
# 29/29 - 5s - loss: 0.0229 - 5s/epoch - 157ms/step
# Epoch 72/100
#
# Epoch 72: loss did not improve from 0.02206
# 29/29 - 3s - loss: 0.0223 - 3s/epoch - 90ms/step
# Epoch 73/100
#
# Epoch 73: loss did not improve from 0.02206
# 29/29 - 3s - loss: 0.0227 - 3s/epoch - 90ms/step
# Epoch 74/100
#
# Epoch 74: loss did not improve from 0.02206
# 29/29 - 3s - loss: 0.0231 - 3s/epoch - 91ms/step
# Epoch 75/100
#
# Epoch 75: loss did not improve from 0.02206
# 29/29 - 4s - loss: 0.0226 - 4s/epoch - 137ms/step
# Epoch 76/100
#
# Epoch 76: loss did not improve from 0.02206
# 29/29 - 4s - loss: 0.0232 - 4s/epoch - 137ms/step
# Epoch 77/100
#
# Epoch 77: loss did not improve from 0.02206
# 29/29 - 3s - loss: 0.0232 - 3s/epoch - 90ms/step
# Epoch 78/100
#
# Epoch 78: loss did not improve from 0.02206
# 29/29 - 3s - loss: 0.0222 - 3s/epoch - 92ms/step
# Epoch 79/100
#
# Epoch 79: loss did not improve from 0.02206
# 29/29 - 3s - loss: 0.0231 - 3s/epoch - 92ms/step
# Epoch 80/100
#
# Epoch 80: loss did not improve from 0.02206
# 29/29 - 4s - loss: 0.0228 - 4s/epoch - 154ms/step
# Epoch 81/100
#
# Epoch 81: loss improved from 0.02206 to 0.02197, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 4s - loss: 0.0220 - 4s/epoch - 132ms/step
# Epoch 82/100
#
# Epoch 82: loss did not improve from 0.02197
# 29/29 - 3s - loss: 0.0224 - 3s/epoch - 93ms/step
# Epoch 83/100
#
# Epoch 83: loss did not improve from 0.02197
# 29/29 - 3s - loss: 0.0221 - 3s/epoch - 91ms/step
# Epoch 84/100
#
# Epoch 84: loss did not improve from 0.02197
# 29/29 - 3s - loss: 0.0231 - 3s/epoch - 100ms/step
# Epoch 85/100
#
# Epoch 85: loss improved from 0.02197 to 0.02138, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 5s - loss: 0.0214 - 5s/epoch - 182ms/step
# Epoch 86/100
#
# Epoch 86: loss did not improve from 0.02138
# 29/29 - 3s - loss: 0.0233 - 3s/epoch - 95ms/step
# Epoch 87/100
#
# Epoch 87: loss did not improve from 0.02138
# 29/29 - 3s - loss: 0.0224 - 3s/epoch - 90ms/step
# Epoch 88/100
#
# Epoch 88: loss did not improve from 0.02138
# 29/29 - 3s - loss: 0.0218 - 3s/epoch - 90ms/step
# Epoch 89/100
#
# Epoch 89: loss did not improve from 0.02138
# 29/29 - 4s - loss: 0.0222 - 4s/epoch - 129ms/step
# Epoch 90/100
#
# Epoch 90: loss did not improve from 0.02138
# 29/29 - 4s - loss: 0.0230 - 4s/epoch - 135ms/step
# Epoch 91/100
#
# Epoch 91: loss did not improve from 0.02138
# 29/29 - 3s - loss: 0.0217 - 3s/epoch - 91ms/step
# Epoch 92/100
#
# Epoch 92: loss did not improve from 0.02138
# 29/29 - 3s - loss: 0.0225 - 3s/epoch - 90ms/step
# Epoch 93/100
#
# Epoch 93: loss did not improve from 0.02138
# 29/29 - 3s - loss: 0.0239 - 3s/epoch - 90ms/step
# Epoch 94/100
#
# Epoch 94: loss did not improve from 0.02138
# 29/29 - 4s - loss: 0.0224 - 4s/epoch - 142ms/step
# Epoch 95/100
#
# Epoch 95: loss did not improve from 0.02138
# 29/29 - 4s - loss: 0.0231 - 4s/epoch - 126ms/step
# Epoch 96/100
#
# Epoch 96: loss did not improve from 0.02138
# 29/29 - 3s - loss: 0.0233 - 3s/epoch - 91ms/step
# Epoch 97/100
#
# Epoch 97: loss did not improve from 0.02138
# 29/29 - 3s - loss: 0.0227 - 3s/epoch - 91ms/step
# Epoch 98/100
#
# Epoch 98: loss improved from 0.02138 to 0.02080, saving model to /content/drive/MyDrive/dataset/save_model.hdf5
# 29/29 - 3s - loss: 0.0208 - 3s/epoch - 107ms/step
# Epoch 99/100
#
# Epoch 99: loss did not improve from 0.02080
# 29/29 - 5s - loss: 0.0218 - 5s/epoch - 178ms/step
# Epoch 100/100
#
# Epoch 100: loss did not improve from 0.02080
# 29/29 - 3s - loss: 0.0222 - 3s/epoch - 93ms/step
# 46/46 [==============================] - 2s 26ms/step

# %%
# Bước 6: Tái sử dụng mô hình
#xử lý dữ liệu test
test = df1[len(train_data)-50:].values
test = test.reshape(-1,1)
sc_test = sc.transform(test)

x_test = []
for i in range(50,test.shape[0]):
  x_test.append(sc_test[i-50:i,0])
x_test = np.array(x_test)
x_test = np.reshape(x_test,(x_test.shape[0],x_test.shape[1],1))

#dữ liệu test
y_test = data[1500:] #giá thực
y_test_predict = final_model.predict(x_test)
y_test_predict = sc.inverse_transform(y_test_predict) #giá dự đoán
# Out:
# 32/32 [==============================] - 1s 30ms/step

# %%
#lập biểu đồ so sánh
train_data1 = df1[50:1500]
test_data1 = df1[1500:]

plt.figure(figsize=(24,8))
plt.plot(df1,label='Giá thực tế',color='red') #đường giá thực
train_data1['Dự đoán'] = y_train_predict #thêm dữ liệu
plt.plot(train_data1['Dự đoán'],label='Giá dự đoán train',color='green') #đường giá dự báo train
test_data1['Dự đoán'] = y_test_predict #thêm dữ liệu
plt.plot(test_data1['Dự đoán'],label='Giá dự đoán test',color='blue') #đường giá dự báo test
plt.title('So sánh giá dự báo và giá thực tế') #đặt tên biểu đồ
plt.xlabel('Thời gian') #đặt tên hàm x
plt.ylabel('Giá đóng cửa (VNĐ)') #đặt tên hàm y
plt.legend() #chú thích
plt.show()
# Out:
# <ipython-input-10-4f5867c1eb90>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data1['Dự đoán'] = y_train_predict #thêm dữ liệu
# <ipython-input-10-4f5867c1eb90>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data1['Dự đoán'] = y_test_predict #thêm dữ liệu

# %%
#r2
print('Độ phù hợp tập train:',r2_score(y_train,y_train_predict))
#mae
print('Sai số tuyệt đối trung bình trên tập train (VNĐ):',mean_absolute_error(y_train,y_train_predict))
#mae
print('Phần trăm sai số tuyệt đối trung bình tập train:',mean_absolute_percentage_error(y_train,y_train_predict))


train_data1
# Out:
# Độ phù hợp tập train: 0.9929578099809776
# Sai số tuyệt đối trung bình trên tập train (VNĐ): 1203.7503825431031
# Phần trăm sai số tuyệt đối trung bình tập train: 0.011312236382119395
#             Đóng cửa       Dự đoán
# Ngày
# 2013-09-19   95139.0  94970.851562
# 2013-09-20   95833.0  95285.210938
# 2013-09-23   95139.0  95914.359375
# 2013-09-24   95833.0  95608.132812
# 2013-09-25   97222.0  95947.617188
# ...              ...           ...
# 2019-07-11   99133.0  99253.992188
# 2019-07-12   98183.0  99371.015625
# 2019-07-15   97549.0  98717.890625
# 2019-07-16   98183.0  98051.914062
# 2019-07-17   99291.0  98337.460938
#
# [1450 rows x 2 columns]

# %%
# Thử dự đoán giá tương lai và so sánh với giá ngày cuối

# Lấy ngày kế tiếp sau ngày cuối cùng trong tập dữ liệu để dự đoán
next_date = df['Ngày'].iloc[-1] + pd.Timedelta(days=1)

# Chuyển đổi ngày kế tiếp sang dạng datetime
next_date = pd.to_datetime(next_date)

# Lấy giá trị của ngày cuối cùng trong tập dữ liệu
next_closing_price = np.array([df['Đóng cửa'].iloc[-1]])  # Lấy giá trị đóng cửa của ngày cuối cùng

# Chuẩn hóa giá trị của ngày cuối cùng
next_closing_price_normalized = sc.transform(next_closing_price.reshape(-1, 1))  # Chuyển thành mảng 2D

# Tạo dự đoán cho ngày kế tiếp bằng mô hình đã huấn luyện
x_next = np.array([sc_train[-50:, 0]])  # Lấy 50 giá đóng cửa gần nhất
x_next = np.reshape(x_next, (x_next.shape[0], x_next.shape[1], 1))
y_next_predict = final_model.predict(x_next)
y_next_predict = sc.inverse_transform(y_next_predict)

# Thêm dữ liệu dự đoán của ngày kế tiếp vào DataFrame
df_next = pd.DataFrame({'Ngày': [next_date], 'Đóng cửa': [y_next_predict[0][0]]})
df1 = pd.concat([df1, df_next])

# Vẽ biểu đồ mới với dự đoán cho ngày kế tiếp
plt.figure(figsize=(15, 5))
plt.plot(df1['Ngày'], df1['Đóng cửa'], label='Giá thực tế', color='red')
plt.plot(train_data1.index, train_data1['Dự đoán'], label='Giá dự đoán train', color='green')
plt.plot(test_data1.index, test_data1['Dự đoán'], label='Giá dự đoán test', color='blue')
plt.scatter([next_date], [y_next_predict[0][0]], color='orange', label='Dự đoán ngày kế tiếp')
plt.xlabel('Thời gian')
plt.ylabel('Giá đóng cửa (VNĐ)')
plt.title('So sánh giá dự báo và giá thực tế')
plt.legend()
plt.show()



# Lấy giá trị của ngày cuối cùng trong tập dữ liệu
actual_closing_price = df['Đóng cửa'].iloc[-1]

# Tạo DataFrame so sánh giá dự đoán với giá ngày cuối trong tập dữ liệu
comparison_df = pd.DataFrame({'Ngày': [next_date], 'Giá dự đoán': [y_next_predict[0][0]], 'Giá ngày trước': [actual_closing_price]})

# In ra bảng so sánh
print(comparison_df)
# Out:
# 1/1 [==============================] - 0s 74ms/step
#         Ngày   Giá dự đoán  Giá ngày trước
# 0 2023-07-22  73666.867188         73500.0
